# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Trainfile.csv')
test = pd.read_csv('Testfile.csv')

# %%
codes, uniques = pd.factorize(data['MSZoning'])
codes
data['MSZoning']
# Out:
# 0       RL
# 1       RL
# 2       RL
# 3       RL
# 4       RL
#         ..
# 1133    RL
# 1134    RL
# 1135    RL
# 1136    RL
# 1137    RL
# Name: MSZoning, Length: 1138, dtype: object

# %%
data
# Out:
#        Idx  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          45       RL         59.0     7227   Pave   NaN      Reg
# 1        2          60       RL          NaN    12227   Pave   NaN      IR1
# 2        3          20       RL         65.0     7800   Pave   NaN      Reg
# 3        4          60       RL         88.0    12665   Pave   NaN      IR1
# 4        5          20       RL        105.0    15431   Pave   NaN      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1133  1134          20       RL         64.0     6762   Pave   NaN      Reg
# 1134  1135          80       RL         88.0     8471   Pave   NaN      IR1
# 1135  1136          20       RL         70.0     8414   Pave   NaN      Reg
# 1136  1137          20       RL          NaN    11838   Pave   NaN      Reg
# 1137  1138          20       RL         85.0    11049   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            HLS    AllPub  ...        0    NaN    NaN         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 3            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1133         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1134         Lvl    AllPub  ...        0    NaN   GdWo         NaN       0
# 1135         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1136         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1137         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         6   2008        WD         Normal     105500
# 1         7   2008        WD         Normal     272000
# 2         6   2009        WD         Normal     130000
# 3         2   2007        WD         Normal     281213
# 4         4   2009        WD         Normal     555000
# ...     ...    ...       ...            ...        ...
# 1133      7   2006       New        Partial     193879
# 1134      7   2006        WD         Normal     151000
# 1135      2   2006        WD         Normal     154500
# 1136      6   2009        WD         Normal     236500
# 1137      1   2008        WD         Normal     179900
#
# [1138 rows x 81 columns]

# %%
for i in range(len(data.columns)):
    j = 0
    while isinstance(data.iloc[j,i], str) != True and math.isnan(data.iloc[j,i]):
        j+=1
    if (isinstance(data.iloc[j, i], str)) == True :
        data.iloc[:,i], uniques = pd.factorize(data.iloc[:,i])
        test.iloc[:,i], uniques = pd.factorize(test.iloc[:,i])

# %%
data = data.replace(-1, np.nan) #replaces all instances of -1 by NaN

# %%
data['Alley'].head(20) # if NaN
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    0.0
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# Name: Alley, dtype: float64

# %%
for i in range(len(data.columns)):
    mean_value=(data.iloc[:,i].mean())
    mean_value_test = (test.iloc[:,i].mean())
    data.iloc[:, i]=data.iloc[:, i].fillna(mean_value) #replaces NaN by mean of the column
    test.iloc[:, i]=test.iloc[:, i].fillna(mean_value_test)

# %%
data.head(25) # now NaN is removed for the whole dataframe
# Out:
#     Idx  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0     1          45         0    59.000000     7227       0    0.5         0
# 1     2          60         0    70.484009    12227       0    0.5         1
# 2     3          20         0    65.000000     7800       0    0.5         0
# 3     4          60         0    88.000000    12665       0    0.5         1
# 4     5          20         0   105.000000    15431       0    0.5         0
# 5     6          20         0    89.000000    12461       0    0.5         0
# 6     7          20         0    71.000000     9204       0    0.5         0
# 7     8          85         0    70.484009    12122       0    0.5         1
# 8     9          20         0    70.000000     7931       0    0.5         0
# 9    10          60         1    64.000000     8791       0    0.5         1
# 10   11          20         0    70.484009    11241       0    0.5         1
# 11   12          60         0    76.000000     9291       0    0.5         1
# 12   13          30         2    50.000000     6000       0    0.5         0
# 13   14          20         0    70.484009    12155       0    0.5         2
# 14   15          40         2    40.000000     5400       0    0.0         0
# 15   16          50         0    50.000000     8405       0    0.5         0
# 16   17          50         0    60.000000     8172       0    0.5         0
# 17   18          20         0    70.000000     7945       0    0.5         0
# 18   19          60         0    70.484009     8068       0    0.5         1
# 19   20          20         0    65.000000     8773       0    0.5         0
# 20   21          70         2    60.000000     3600       0    1.0         0
# 21   22          60         0    74.000000    10927       0    0.5         0
# 22   23          90         0    75.000000     9825       0    0.5         0
# 23   24         160         2    21.000000     1533       0    0.5         0
# 24   25          60         0   313.000000    63887       0    0.5         2
#
#     LandContour  Utilities  ...  PoolArea  PoolQC     Fence  MiscFeature  \
# 0             0          0  ...         0     0.8  0.754464     0.095238
# 1             1          0  ...         0     0.8  0.754464     0.095238
# 2             1          0  ...         0     0.8  0.000000     0.095238
# 3             1          0  ...         0     0.8  0.754464     0.095238
# 4             1          0  ...         0     0.8  0.754464     0.095238
# 5             1          0  ...         0     0.8  1.000000     0.095238
# 6             1          0  ...         0     0.8  0.754464     0.095238
# 7             1          0  ...         0     0.8  0.754464     0.095238
# 8             1          0  ...         0     0.8  0.754464     0.095238
# 9             1          0  ...         0     0.8  0.754464     0.095238
# 10            1          0  ...         0     0.8  0.754464     0.000000
# 11            1          0  ...         0     0.8  0.754464     0.095238
# 12            1          0  ...         0     0.8  0.000000     0.095238
# 13            1          0  ...         0     0.8  0.754464     0.095238
# 14            1          0  ...         0     0.8  0.754464     0.095238
# 15            1          0  ...         0     0.8  0.754464     0.095238
# 16            1          0  ...         0     0.8  0.754464     0.095238
# 17            1          0  ...         0     0.8  0.754464     0.095238
# 18            1          0  ...         0     0.8  0.754464     0.095238
# 19            1          0  ...         0     0.8  0.754464     0.095238
# 20            1          0  ...         0     0.8  0.754464     0.095238
# 21            1          0  ...         0     0.8  0.754464     0.095238
# 22            1          0  ...         0     0.8  0.754464     0.095238
# 23            1          0  ...         0     0.8  0.754464     0.095238
# 24            2          0  ...       480     0.0  0.754464     0.095238
#
#     MiscVal  MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0         0       6    2008         0              0     105500
# 1         0       7    2008         0              0     272000
# 2         0       6    2009         0              0     130000
# 3         0       2    2007         0              0     281213
# 4         0       4    2009         0              0     555000
# 5         0       7    2006         0              0     262000
# 6         0       8    2008         1              0     124000
# 7         0       7    2008         0              0     178400
# 8         0       6    2008         0              0     155000
# 9         0       5    2008         0              0     207500
# 10      700       3    2010         0              0     149000
# 11        0       6    2008         0              0     187000
# 12        0       7    2006         0              0     110500
# 13        0       3    2007         0              0     163500
# 14        0      10    2007         0              0     152000
# 15        0       4    2009         0              0      98000
# 16        0       5    2008         0              0     135000
# 17        0       5    2006         0              0     141000
# 18        0      12    2009         2              0     200000
# 19        0       5    2010         0              0     185500
# 20        0      10    2006         0              0     114504
# 21        0       6    2006         0              0     275000
# 22        0       5    2010         0              0     100000
# 23        0       5    2009         0              0      97000
# 24        0       1    2008         3              1     160000
#
# [25 rows x 81 columns]

# %%
data = data.drop(columns = ['Idx'])
test = test.drop(columns = ['Idx'])

# %%
data.std(axis = 0).head(20)
# Out:
# MSSubClass        42.519037
# MSZoning           0.841260
# LotFrontage       22.680339
# LotArea         7742.762753
# Street             0.066168
# Alley              0.120465
# LotShape           0.642296
# LandContour        0.420058
# Utilities          0.000000
# LotConfig          0.619488
# LandSlope          0.223373
# Neighborhood       6.365002
# Condition1         1.131696
# Condition2         0.248922
# BldgType           1.009784
# HouseStyle         1.201011
# OverallQual        1.374100
# OverallCond        1.112681
# YearBuilt         30.388180
# YearRemodAdd      20.618711
# dtype: float64

# %%
print(data.shape) # dropped the column on ids
# Out:
# (1138, 80)

# %%
data
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0             45         0    59.000000     7227       0    0.5         0
# 1             60         0    70.484009    12227       0    0.5         1
# 2             20         0    65.000000     7800       0    0.5         0
# 3             60         0    88.000000    12665       0    0.5         1
# 4             20         0   105.000000    15431       0    0.5         0
# ...          ...       ...          ...      ...     ...    ...       ...
# 1133          20         0    64.000000     6762       0    0.5         0
# 1134          80         0    88.000000     8471       0    0.5         1
# 1135          20         0    70.000000     8414       0    0.5         0
# 1136          20         0    70.484009    11838       0    0.5         0
# 1137          20         0    85.000000    11049       0    0.5         0
#
#       LandContour  Utilities  LotConfig  ...  PoolArea  PoolQC     Fence  \
# 0               0          0          0  ...         0     0.8  0.754464
# 1               1          0          0  ...         0     0.8  0.754464
# 2               1          0          1  ...         0     0.8  0.000000
# 3               1          0          1  ...         0     0.8  0.754464
# 4               1          0          1  ...         0     0.8  0.754464
# ...           ...        ...        ...  ...       ...     ...       ...
# 1133            1          0          1  ...         0     0.8  0.754464
# 1134            1          0          0  ...         0     0.8  2.000000
# 1135            1          0          1  ...         0     0.8  0.000000
# 1136            1          0          1  ...         0     0.8  0.754464
# 1137            1          0          0  ...         0     0.8  0.754464
#
#       MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0        0.095238        0       6    2008         0              0     105500
# 1        0.095238        0       7    2008         0              0     272000
# 2        0.095238        0       6    2009         0              0     130000
# 3        0.095238        0       2    2007         0              0     281213
# 4        0.095238        0       4    2009         0              0     555000
# ...           ...      ...     ...     ...       ...            ...        ...
# 1133     0.095238        0       7    2006         3              1     193879
# 1134     0.095238        0       7    2006         0              0     151000
# 1135     0.095238        0       2    2006         0              0     154500
# 1136     0.095238        0       6    2009         0              0     236500
# 1137     0.095238        0       1    2008         0              0     179900
#
# [1138 rows x 80 columns]

# %%
devia = data.std()
devia.head(10)
# Out:
# MSSubClass       42.519037
# MSZoning          0.841260
# LotFrontage      22.680339
# LotArea        7742.762753
# Street            0.066168
# Alley             0.120465
# LotShape          0.642296
# LandContour       0.420058
# Utilities         0.000000
# LotConfig         0.619488
# dtype: float64

# %%
i = []
for j in range(len(data.columns)):
    if devia[j] < 1:
        i.append(j)
        
data = data.drop(data.columns[i], axis=1)
test = test.drop(test.columns[i], axis = 1) 
data
# Out:
#       MSSubClass  LotFrontage  LotArea  Neighborhood  Condition1  BldgType  \
# 0             45    59.000000     7227             0           0         0
# 1             60    70.484009    12227             1           1         0
# 2             20    65.000000     7800             2           2         0
# 3             60    88.000000    12665             3           2         0
# 4             20   105.000000    15431             4           2         0
# ...          ...          ...      ...           ...         ...       ...
# 1133          20    64.000000     6762            11           2         0
# 1134          80    88.000000     8471             2           2         0
# 1135          20    70.000000     8414             2           2         0
# 1136          20    70.484009    11838            11           2         0
# 1137          20    85.000000    11049            11           2         0
#
#       HouseStyle  OverallQual  OverallCond  YearBuilt  ...  OpenPorchSF  \
# 0              0            6            6       1954  ...            0
# 1              1            6            7       1977  ...          282
# 2              2            5            7       1967  ...            0
# 3              1            8            5       2005  ...           39
# 4              2           10            5       2008  ...           72
# ...          ...          ...          ...        ...  ...          ...
# 1133           2            7            5       2006  ...           55
# 1134           5            6            7       1977  ...           12
# 1135           2            6            8       1963  ...            0
# 1136           2            8            5       2001  ...          151
# 1137           2            8            5       2007  ...           30
#
#       EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  \
# 0                 0          0            0         0        0       6
# 1                 0          0            0         0        0       7
# 2                 0          0            0         0        0       6
# 3                 0          0            0         0        0       2
# 4                 0          0          170         0        0       4
# ...             ...        ...          ...       ...      ...     ...
# 1133              0          0            0         0        0       7
# 1134              0          0            0         0        0       7
# 1135              0          0            0         0        0       2
# 1136              0          0            0         0        0       6
# 1137              0          0            0         0        0       1
#
#       YrSold  SaleType  SalePrice
# 0       2008         0     105500
# 1       2008         0     272000
# 2       2009         0     130000
# 3       2007         0     281213
# 4       2009         0     555000
# ...      ...       ...        ...
# 1133    2006         3     193879
# 1134    2006         0     151000
# 1135    2006         0     154500
# 1136    2009         0     236500
# 1137    2008         0     179900
#
# [1138 rows x 37 columns]

# %%
test
# Out:
#      MSSubClass  LotFrontage  LotArea  Neighborhood  Condition1  BldgType  \
# 0            20    68.000000     9571             0           0         0
# 1            20    68.501901     9790             1           1         0
# 2            60    41.000000    12393             2           0         0
# 3            20   100.000000    10004             3           0         0
# 4            45    55.000000     5500             4           0         0
# ..          ...          ...      ...           ...         ...       ...
# 317          20    65.000000     8775             2           0         0
# 318          50    79.000000    12327            21           0         0
# 319          20    73.000000     9300             3           1         0
# 320          75    87.000000    18386             4           0         0
# 321          20    98.000000    11428             9           0         0
#
#      HouseStyle  OverallQual  OverallCond  YearBuilt  ...  OpenPorchSF  \
# 0             0            5            3       1958  ...            0
# 1             0            6            5       1967  ...            0
# 2             1            7            5       2004  ...           48
# 3             0            6            6       1964  ...            0
# 4             2            4            6       1956  ...            0
# ..          ...          ...          ...        ...  ...          ...
# 317           0            5            5       1994  ...           64
# 318           5            8            8       1983  ...           40
# 319           0            5            5       1960  ...            0
# 320           6            7            9       1880  ...            0
# 321           0            8            5       2006  ...           44
#
#      EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# 0                0          0            0         0        0       6    2009
# 1                0          0          197         0        0       9    2009
# 2                0          0            0         0        0       9    2006
# 3                0          0          152         0        0       2    2009
# 4                0          0            0         0        0       4    2007
# ..             ...        ...          ...       ...      ...     ...     ...
# 317              0          0            0         0        0       4    2007
# 318              0          0            0         0        0       9    2009
# 319              0          0          143         0        0       4    2010
# 320              0          0            0         0        0       5    2008
# 321              0          0            0         0        0       5    2007
#
#      SaleType  SalePrice
# 0           0      60000
# 1           1     161500
# 2           1     195000
# 3           1     167000
# 4           1     103200
# ..        ...        ...
# 317         1     126000
# 318         1     316600
# 319         1     167500
# 320         1     295000
# 321         1     250000
#
# [322 rows x 37 columns]

# %%
my_data = (data - data.mean())/data.std()
my_data_test = (test - test.mean())/test.std()

# %%
X = my_data.iloc[:,0:len(data.columns)-1]
ones = np.ones([X.shape[0],1])
X = np.concatenate((ones,X),axis=1)

y = my_data.iloc[:,len(data.columns)-1:len(data.columns)].values
theta = np.zeros([1,len(data.columns)])

alpha = 0.01
iters = 1000

# %%
#computecost
def computeCost(X,y,theta):
    error = np.power(((X @ theta.T)-y),2)
    return np.sum(error)/(2 * len(X))

# %%
def gradientDescent(X,y,theta,iters,alpha):
    cost = np.zeros(iters)
    for i in range(iters):
        theta = theta - (alpha/len(X)) * np.sum(X * (X @ theta.T - y), axis=0)
        cost[i] = computeCost(X, y, theta)
    
    return theta,cost

#running the grdaient descent and cost function
g,cost = gradientDescent(X,y,theta,iters,alpha)
print(g)
finalCost = computeCost(X,y,g)
print(finalCost)
# Out:
# [[-5.63251847e-16 -9.67518443e-02 -9.26927477e-03  4.10492329e-02
#    3.65180425e-02 -2.64968351e-02 -2.09734333e-03 -1.17568517e-02
#    3.58232781e-01  5.87573143e-02  1.20704170e-01  5.63604760e-02
#   -1.28746866e-02  6.06148050e-03  6.04847438e-02  1.01360928e-02
#    6.46575634e-02  1.19607642e-02 -2.24932117e-02  4.82818247e-02
#    9.78672385e-02  1.01601645e-01 -7.75729083e-04  1.55496629e-01
#    4.52800956e-02  2.29841375e-02  9.93638055e-02  5.85806231e-02
#    8.63328700e-04  1.21969897e-02  2.26915462e-02  6.63008091e-02
#   -2.01241193e-02  1.41434162e-05  3.30606260e-03 -4.38685201e-03
#    5.29603716e-02]]
# 0.10177028965285591

# %%
fig, ax = plt.subplots()  
ax.plot(np.arange(iters), cost, 'r')  
ax.set_xlabel('Iterations')  
ax.set_ylabel('Cost')  
ax.set_title('Error vs. Iterations. We can stop after about 400 iterations.')
# Out:
# Text(0.5, 1.0, 'Error vs. Iterations. We can stop after about 400 iterations.')

# %%
X = my_data_test.iloc[:,0:len(data.columns)-1]
ones = np.ones([X.shape[0],1])
X = np.concatenate((ones,X),axis=1)

y = my_data_test.iloc[:,len(data.columns)-1:len(data.columns)].values

# %%
my_data_test
# Out:
#      MSSubClass   LotFrontage   LotArea  Neighborhood  Condition1  BldgType  \
# 0     -0.827980 -2.574258e-02 -0.116678     -1.293688   -0.293431  -0.37928
# 1     -0.827980  1.457753e-15 -0.102527     -1.134814    0.887628  -0.37928
# 2      0.136250 -1.410576e+00  0.065666     -0.975940   -0.293431  -0.37928
# 3     -0.827980  1.615542e+00 -0.088699     -0.817066   -0.293431  -0.37928
# 4     -0.225336 -6.925144e-01 -0.379725     -0.658192   -0.293431  -0.37928
# ..          ...           ...       ...           ...         ...       ...
# 317   -0.827980 -1.796130e-01 -0.168111     -0.975940   -0.293431  -0.37928
# 318   -0.104808  5.384490e-01  0.061401      2.042666   -0.293431  -0.37928
# 319   -0.827980  2.307081e-01 -0.134188     -0.817066    0.887628  -0.37928
# 320    0.497836  9.487701e-01  0.452902     -0.658192   -0.293431  -0.37928
# 321   -0.827980  1.512962e+00  0.003312      0.136178   -0.293431  -0.37928
#
#      HouseStyle  OverallQual  OverallCond  YearBuilt  ...  OpenPorchSF  \
# 0     -0.679278    -0.746057    -2.246636  -0.481302  ...    -0.690755
# 1     -0.679278    -0.039497    -0.447092  -0.176891  ...    -0.690755
# 2     -0.137873     0.667063    -0.447092   1.074579  ...     0.067775
# 3     -0.679278    -0.039497     0.452680  -0.278361  ...    -0.690755
# 4      0.403531    -1.452617     0.452680  -0.548949  ...    -0.690755
# ..          ...          ...          ...        ...  ...          ...
# 317   -0.679278    -0.746057    -0.447092   0.736344  ...     0.320618
# 318    2.027746     1.373623     2.252225   0.364286  ...    -0.058647
# 319   -0.679278    -0.746057    -0.447092  -0.413655  ...    -0.690755
# 320    2.569150     0.667063     3.151997  -3.119537  ...    -0.690755
# 321   -0.679278     1.373623    -0.447092   1.142226  ...     0.004564
#
#      EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea   MiscVal    MoSold  \
# 0        -0.329331  -0.123492    -0.272447 -0.077756 -0.111638 -0.108311
# 1        -0.329331  -0.123492     2.923265 -0.077756 -0.111638  1.028950
# 2        -0.329331  -0.123492    -0.272447 -0.077756 -0.111638  1.028950
# 3        -0.329331  -0.123492     2.193280 -0.077756 -0.111638 -1.624658
# 4        -0.329331  -0.123492    -0.272447 -0.077756 -0.111638 -0.866484
# ..             ...        ...          ...       ...       ...       ...
# 317      -0.329331  -0.123492    -0.272447 -0.077756 -0.111638 -0.866484
# 318      -0.329331  -0.123492    -0.272447 -0.077756 -0.111638  1.028950
# 319      -0.329331  -0.123492     2.047283 -0.077756 -0.111638 -0.866484
# 320      -0.329331  -0.123492    -0.272447 -0.077756 -0.111638 -0.487397
# 321      -0.329331  -0.123492    -0.272447 -0.077756 -0.111638 -0.487397
#
#        YrSold  SaleType  SalePrice
# 0    0.974433 -2.022007  -1.429418
# 1    0.974433 -0.228381  -0.282941
# 2   -1.282886 -0.228381   0.095453
# 3    0.974433 -0.228381  -0.220816
# 4   -0.530447 -0.228381  -0.941459
# ..        ...       ...        ...
# 317 -0.530447 -0.228381  -0.683925
# 318  0.974433 -0.228381   1.468967
# 319  1.726872 -0.228381  -0.215168
# 320  0.221993 -0.228381   1.224988
# 321 -0.530447 -0.228381   0.716697
#
# [322 rows x 37 columns]

# %%
# x is 322 x 70
#theta is 1 x 70
new_y = X@g.T
me = test.iloc[:, len(data.columns)-1].mean()
st = test.iloc[:, len(data.columns)-1].std()
for i in range(322):
    new_y[i] = new_y[i] * st + me
    y[i] = y[i] * st + me
new_y
# Out:
# array([[ 94840.80309985],
#        [182569.17717366],
#        [228212.27070927],
#        [190811.77229703],
#        [ 50604.39011847],
#        [342819.43469758],
#        [155813.98847272],
#        [206683.82627451],
#        [251036.41444722],
#        [168261.36256407],
#        [ 39133.5631915 ],
#        [ 95030.78034883],
#        [369768.44521243],
#        [335124.3933491 ],
#        [103455.34697004],
#        [176353.99674684],
#        [238394.71606776],
#        [158519.0489916 ],
#        [112832.28571932],
#        [230568.79700515],
#        [402927.42591541],
#        [315684.0828797 ],
#        [186197.54079039],
#        [285325.88978721],
#        [120612.12416821],
#        [126720.53282971],
#        [159158.31243655],
#        [121857.29245919],
#        [238161.66494922],
#        [121556.06800994],
#        [294528.71244538],
#        [113347.94127266],
#        [214701.99618295],
#        [147978.15268042],
#        [156255.69346524],
#        [202508.15839114],
#        [134129.91180271],
#        [335171.02838929],
#        [176321.80446243],
#        [ 60275.34894447],
#        [118991.92167422],
#        [184133.52728418],
#        [125748.50791504],
#        [344868.63476678],
#        [147116.87165948],
#        [246129.35221972],
#        [104160.33905571],
#        [109860.09358856],
#        [136088.90283764],
#        [168969.73986155],
#        [298645.89098453],
#        [242685.28096478],
#        [ -5276.70260769],
#        [276726.66557449],
#        [185493.51862291],
#        [224065.49515138],
#        [231198.23437685],
#        [322318.69402964],
#        [ 97648.01094694],
#        [254497.57409629],
#        [204600.74749099],
#        [243030.94606871],
#        [ 94553.68180975],
#        [221279.05282741],
#        [179780.04828694],
#        [225455.69368285],
#        [403322.33693283],
#        [207669.4123309 ],
#        [275258.3483335 ],
#        [146251.6936213 ],
#        [153221.49405438],
#        [340453.2232204 ],
#        [151797.9648254 ],
#        [155762.8081353 ],
#        [144051.80605686],
#        [331068.5172734 ],
#        [317968.2761434 ],
#        [288434.91147573],
#        [169591.58714608],
#        [136678.69828497],
#        [220886.55572308],
#        [ 87408.00938569],
#        [290093.9340198 ],
#        [281940.16433381],
#        [223258.99452816],
#        [112017.40980981],
#        [193211.77800746],
#        [ 96551.17672103],
#        [154938.31743057],
#        [ 97939.65512747],
#        [226551.66015268],
#        [225299.30509563],
#        [210750.88728018],
#        [214344.12832037],
#        [128614.19257756],
#        [328740.49611675],
#        [314323.69130921],
#        [368766.8931652 ],
#        [241324.05478458],
#        [115815.76309772],
#        [228660.57067957],
#        [155936.40928457],
#        [208956.4701792 ],
#        [127737.43797348],
#        [218794.83971863],
#        [270217.1738213 ],
#        [197439.06248164],
#        [190137.17334682],
#        [ 64383.89051968],
#        [142071.74626985],
#        [189231.31437685],
#        [225389.28983621],
#        [164386.72204736],
#        [296092.32845165],
#        [146094.60841882],
#        [135448.597417  ],
#        [ 67481.04100127],
#        [ 89004.85448114],
#        [151623.88524387],
#        [246096.41229107],
#        [120122.20565966],
#        [116767.9485989 ],
#        [ 82794.6759563 ],
#        [319973.85427126],
#        [155630.19926904],
#        [127218.69314557],
#        [175519.31527858],
#        [213858.09276225],
#        [167208.73007804],
#        [262852.58349871],
#        [184618.49058618],
#        [215951.95303288],
#        [187330.06227563],
#        [199974.45507532],
#        [223946.54152737],
#        [169796.24382152],
#        [122431.70724596],
#        [ 85946.72672828],
#        [195351.61249438],
#        [141515.22399718],
#        [149259.78862359],
#        [264355.16036339],
#        [264557.12551428],
#        [ 44952.0565584 ],
#        [211948.41102433],
#        [167620.68355423],
#        [157083.10340153],
#        [248429.45437508],
#        [104517.87946254],
#        [115016.90332806],
#        [167123.38102795],
#        [204735.11066893],
#        [109255.11916319],
#        [178571.48337339],
#        [129561.24076716],
#        [239868.66369023],
#        [140406.17450329],
#        [111974.13040067],
#        [219843.1948842 ],
#        [ 62167.47789878],
#        [309393.40385342],
#        [ 53461.81613479],
#        [ 97220.53614389],
#        [268889.3753097 ],
#        [293063.52378764],
#        [ 37141.84193324],
#        [260018.03620873],
#        [181402.56796926],
#        [229336.74510719],
#        [136147.41696526],
#        [350404.91011003],
#        [ 82895.94798609],
#        [184139.06481122],
#        [163565.38878628],
#        [119781.11062141],
#        [135917.74480728],
#        [118147.60785594],
#        [161532.18510021],
#        [338831.12302994],
#        [236833.83178554],
#        [204274.77222004],
#        [198840.00634903],
#        [149001.56386498],
#        [208701.45193463],
#        [132022.86305755],
#        [306669.61675647],
#        [207385.19529634],
#        [ 82011.17539358],
#        [348960.08167971],
#        [189461.15428878],
#        [278093.72554002],
#        [278914.6709257 ],
#        [118366.00552744],
#        [261967.3828282 ],
#        [241640.37420048],
#        [120513.3258878 ],
#        [254561.47101752],
#        [114502.37974777],
#        [199074.97399402],
#        [379531.65927567],
#        [241995.28745147],
#        [126362.28281351],
#        [127254.74812239],
#        [173790.96092451],
#        [ 78850.64951872],
#        [218605.24085408],
#        [128096.78596943],
#        [223995.48502776],
#        [305292.52618741],
#        [172860.12356692],
#        [ 91258.87895444],
#        [221503.39078817],
#        [302389.21138537],
#        [147675.65692699],
#        [ 36555.40760709],
#        [203569.86054792],
#        [171580.4326137 ],
#        [151129.59220442],
#        [194872.22637873],
#        [ 81437.65233283],
#        [243263.81435926],
#        [173849.71001358],
#        [ 83750.00574549],
#        [241438.49349757],
#        [330388.13990257],
#        [122056.30839018],
#        [149607.05958746],
#        [ 32902.15693278],
#        [129213.04248513],
#        [176382.08309346],
#        [ 41189.57230871],
#        [ 19698.08465434],
#        [ 67217.05718887],
#        [153196.68404992],
#        [230238.74083908],
#        [198189.15834479],
#        [ 83378.89775065],
#        [187056.52927461],
#        [ 80448.94618696],
#        [153332.76484599],
#        [137722.82348137],
#        [200276.78591202],
#        [162275.33771964],
#        [ 97469.74539927],
#        [239700.17360777],
#        [275059.66265409],
#        [343716.77304796],
#        [ 90228.37340393],
#        [123846.96512256],
#        [391896.53513328],
#        [154403.99337986],
#        [168819.1928788 ],
#        [ 49215.17099657],
#        [ 31250.17244091],
#        [ 80221.42255978],
#        [ 98360.59754657],
#        [178107.63452721],
#        [121628.34680519],
#        [233563.11648851],
#        [252868.64672374],
#        [239251.11728256],
#        [ 80984.43512554],
#        [ 90934.87063824],
#        [144403.00399925],
#        [106981.25647093],
#        [227617.17400025],
#        [215266.38702586],
#        [112145.51920518],
#        [232811.36353834],
#        [152394.84128071],
#        [246315.58116348],
#        [124498.20377937],
#        [311112.97491767],
#        [168961.36483308],
#        [120655.29444709],
#        [196332.18133719],
#        [141749.51625458],
#        [134610.52589317],
#        [229842.22494495],
#        [106147.85284385],
#        [215319.02970506],
#        [184979.02616874],
#        [142847.41146163],
#        [139955.01631928],
#        [160895.64746073],
#        [151922.03522061],
#        [265950.47663123],
#        [194234.91586194],
#        [127162.665645  ],
#        [208069.08862551],
#        [126218.64822164],
#        [ 90905.44857248],
#        [226256.72410789],
#        [314476.72721924],
#        [207205.59655833],
#        [233242.37956598],
#        [285614.0837211 ],
#        [244223.46166766],
#        [134612.15830542],
#        [119941.77049843],
#        [182610.68202756],
#        [181895.73569145],
#        [154908.05186593],
#        [111002.70290438],
#        [113014.16618644],
#        [312778.30600749],
#        [253098.20211766],
#        [226031.41050272],
#        [110712.16499384],
#        [330752.841227  ],
#        [326908.52847734],
#        [169692.19884872],
#        [101141.09506615],
#        [235934.15484181],
#        [255550.42718505],
#        [146834.37079827],
#        [516455.59542399],
#        [129787.63385824],
#        [309213.71193296],
#        [153209.00053351],
#        [303853.65964605],
#        [270748.16235886]])

# %%
mape = 0
for i in range(322):
    mape += abs(new_y[i] - y[i])/y[i]
mape/=3.22
print('Accuracy =', float(100-mape),'%')
# Out:
# Accuracy = 86.01187343696887 %
