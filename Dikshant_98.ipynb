# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.set_style('whitegrid')

# %%
train=pd.DataFrame(pd.read_csv(r'Trainfile.csv'))
test=pd.DataFrame(pd.read_csv(r'Testfile.csv'))
pd.set_option('display.max_columns', None)
train.drop(columns=['Idx'],inplace=True)             #dropping the Idx coloumn
test.drop(columns=['Idx'],inplace=True)

# %%
train[:5]
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          45       RL         59.0     7227   Pave   NaN      Reg
# 1          60       RL          NaN    12227   Pave   NaN      IR1
# 2          20       RL         65.0     7800   Pave   NaN      Reg
# 3          60       RL         88.0    12665   Pave   NaN      IR1
# 4          20       RL        105.0    15431   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         HLS    AllPub    Corner       Mod        NAmes     Artery
# 1         Lvl    AllPub    Corner       Gtl       NWAmes       PosN
# 2         Lvl    AllPub    Inside       Gtl       Sawyer       Norm
# 3         Lvl    AllPub    Inside       Gtl       Timber       Norm
# 4         Lvl    AllPub    Inside       Gtl      NridgHt       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     1.5Unf            6            6       1954
# 1       Norm     1Fam     2Story            6            7       1977
# 2       Norm     1Fam     1Story            5            7       1967
# 3       Norm     1Fam     2Story            8            5       2005
# 4       Norm     1Fam     1Story           10            5       2008
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          1954     Gable  CompShg     MetalSd     MetalSd       None
# 1          1995     Gable  CompShg     HdBoard     HdBoard    BrkFace
# 2          2004       Hip  CompShg     HdBoard     HdBoard    BrkFace
# 3          2006       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 4          2008       Hip  CompShg     VinylSd     VinylSd      Stone
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0         0.0        TA        TA     CBlock       TA       TA           No
# 1       424.0        TA        Gd     CBlock       Gd       Gd           No
# 2        89.0        TA        TA      PConc       TA       TA           No
# 3       245.0        Gd        TA      PConc       Gd       Gd           Gd
# 4       200.0        Ex        TA      PConc       Ex       TA           Gd
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          Unf           0          Unf           0        832          832
# 1          ALQ         896          Unf           0        434         1330
# 2          ALQ         450          Unf           0        414          864
# 3          Unf           0          Unf           0       1094         1094
# 4          GLQ        1767          ALQ         539        788         3094
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Gd          Y      SBrkr       832         0             0
# 1    GasA        TA          Y      SBrkr      1542      1330             0
# 2    GasA        Ex          Y      SBrkr       899         0             0
# 3    GasA        Ex          Y      SBrkr      1133      1349             0
# 4    GasA        Ex          Y      SBrkr      2402         0             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0        832             0             0         1         0             2
# 1       2872             1             0         2         1             4
# 2        899             0             0         1         0             3
# 3       2482             0             0         2         1             4
# 4       2402             1             0         2         0             2
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             4        Typ           0         NaN
# 1             1          TA            11        Typ           1          TA
# 2             1          Gd             5        Typ           0         NaN
# 3             1          Gd             9        Typ           1          Gd
# 4             1          Ex            10        Typ           2          Gd
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Detchd       1962.0          Unf           2         528         TA
# 1     Attchd       1977.0          Fin           2         619         TA
# 2     Attchd       1967.0          Fin           1         288         TA
# 3    BuiltIn       2005.0          Fin           3         642         TA
# 4     Attchd       2008.0          Fin           3         672         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0            0              0          0
# 1         TA          Y         550          282              0          0
# 2         TA          Y          64            0              0          0
# 3         TA          Y         144           39              0          0
# 4         TA          Y           0           72              0          0
#
#    ScreenPorch  PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN    NaN         NaN        0       6    2008
# 1            0         0    NaN    NaN         NaN        0       7    2008
# 2            0         0    NaN  MnPrv         NaN        0       6    2009
# 3            0         0    NaN    NaN         NaN        0       2    2007
# 4          170         0    NaN    NaN         NaN        0       4    2009
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal     105500
# 1       WD        Normal     272000
# 2       WD        Normal     130000
# 3       WD        Normal     281213
# 4       WD        Normal     555000

# %%
train.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1138.000000   938.000000    1138.000000  1138.000000  1138.000000
# mean     57.618629    70.484009   10273.514060     6.111599     5.597540
# std      42.519037    24.983885    7742.762753     1.374100     1.112681
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7560.000000     5.000000     5.000000
# 50%      50.000000    70.000000    9496.000000     6.000000     5.000000
# 75%      70.000000    80.000000   11596.000000     7.000000     6.000000
# max     190.000000   313.000000  159000.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  \
# count  1138.000000   1138.000000  1132.000000  1138.000000  1138.000000
# mean   1970.995606   1984.790861   102.795053   440.527241    42.954306
# std      30.388180     20.618711   179.089584   452.563788   155.308430
# min    1872.000000   1950.000000     0.000000     0.000000     0.000000
# 25%    1954.000000   1967.000000     0.000000     0.000000     0.000000
# 50%    1972.000000   1993.000000     0.000000   384.500000     0.000000
# 75%    2000.000000   2004.000000   164.250000   706.000000     0.000000
# max    2010.000000   2010.000000  1600.000000  5644.000000  1474.000000
#
#          BsmtUnfSF  TotalBsmtSF     1stFlrSF     2ndFlrSF  LowQualFinSF  \
# count  1138.000000  1138.000000  1138.000000  1138.000000   1138.000000
# mean    562.456063  1045.937610  1153.873462   355.300527      6.057996
# std     442.891582   438.202684   385.710814   438.400418     49.254675
# min       0.000000     0.000000   334.000000     0.000000      0.000000
# 25%     216.000000   788.000000   866.750000     0.000000      0.000000
# 50%     464.000000   984.000000  1080.000000     0.000000      0.000000
# 75%     796.750000  1268.000000  1378.000000   741.000000      0.000000
# max    2336.000000  6110.000000  4692.000000  2065.000000    572.000000
#
#          GrLivArea  BsmtFullBath  BsmtHalfBath     FullBath     HalfBath  \
# count  1138.000000   1138.000000   1138.000000  1138.000000  1138.000000
# mean   1515.231986      0.425308      0.062390     1.556239     0.391037
# std     528.966115      0.518905      0.245577     0.549166     0.505892
# min     334.000000      0.000000      0.000000     0.000000     0.000000
# 25%    1130.250000      0.000000      0.000000     1.000000     0.000000
# 50%    1469.000000      0.000000      0.000000     2.000000     0.000000
# 75%    1774.000000      1.000000      0.000000     2.000000     1.000000
# max    5642.000000      3.000000      2.000000     3.000000     2.000000
#
#        BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd   Fireplaces  GarageYrBlt  \
# count   1138.000000   1138.000000   1138.000000  1138.000000  1070.000000
# mean       2.873462      1.049209      6.538664     0.603691  1978.552336
# std        0.822816      0.220426      1.636436     0.634860    24.434762
# min        0.000000      1.000000      2.000000     0.000000  1900.000000
# 25%        2.000000      1.000000      5.000000     0.000000  1961.250000
# 50%        3.000000      1.000000      6.000000     1.000000  1979.000000
# 75%        3.000000      1.000000      7.000000     1.000000  2002.000000
# max        8.000000      3.000000     14.000000     3.000000  2010.000000
#
#         GarageCars   GarageArea   WoodDeckSF  OpenPorchSF  EnclosedPorch  \
# count  1138.000000  1138.000000  1138.000000  1138.000000    1138.000000
# mean      1.750439   470.307557    90.373462    47.494728      23.067663
# std       0.760228   217.823059   121.890193    67.077467      62.790978
# min       0.000000     0.000000     0.000000     0.000000       0.000000
# 25%       1.000000   312.750000     0.000000     0.000000       0.000000
# 50%       2.000000   478.000000     0.000000    24.000000       0.000000
# 75%       2.000000   576.000000   168.000000    72.000000       0.000000
# max       4.000000  1418.000000   857.000000   523.000000     552.000000
#
#          3SsnPorch  ScreenPorch     PoolArea       MiscVal       MoSold  \
# count  1138.000000  1138.000000  1138.000000   1138.000000  1138.000000
# mean      2.947276    14.570299     2.434974     40.179262     6.332162
# std      25.120656    53.994274    36.868419    496.795058     2.722983
# min       0.000000     0.000000     0.000000      0.000000     1.000000
# 25%       0.000000     0.000000     0.000000      0.000000     5.000000
# 50%       0.000000     0.000000     0.000000      0.000000     6.000000
# 75%       0.000000     0.000000     0.000000      0.000000     8.000000
# max     320.000000   410.000000   648.000000  15500.000000    12.000000
#
#             YrSold      SalePrice
# count  1138.000000    1138.000000
# mean   2007.847100  179328.707381
# std       1.326741   76642.678880
# min    2006.000000   34900.000000
# 25%    2007.000000  129900.000000
# 50%    2008.000000  162450.000000
# 75%    2009.000000  210750.000000
# max    2010.000000  745000.000000

# %%
sns.distplot(a=train['SalePrice'])
plt.show()

# %%
# the distribution is more to the left
# so to make it evenly distributed take log of saleprice

# %%
sns.distplot(a=np.log(train['SalePrice']))
plt.show()

# %%
# relacing nan values in categorical coloumns with mode values

def nan_handling(df):
    df['LotFrontage']=df.groupby('Neighborhood')['LotFrontage'].transform(lambda x:x.fillna(x.median()))
    df['Utilities'].fillna(train['Utilities'].mode(),inplace=True)
    df['MasVnrArea'].fillna(df['MasVnrArea'].mode()[0],inplace=True)
    df['MasVnrType'].fillna(df['MasVnrType'].mode()[0],inplace=True)
    df['Electrical'].fillna(df['Electrical'].mode()[0],inplace=True)
    return df

# %%
train=nan_handling(train)
test=nan_handling(test)

# %%
# normalizing all coloumns 

def normalize(ser):
    if ser.max()-ser.min()==0.0: return ser*1.0
    norm_ser=(ser-ser.min())/(ser.max()-ser.min())
    return norm_ser

# %%
# encoding categrical features
def encode(ser):
    decode=ser.value_counts().index.tolist()[::-1]
    if (ser.isna()).mean()>0.0:
        decode=[np.nan]+decode
    encoded_ser=ser.replace({v:i for i,v in enumerate(decode)})
    return encoded_ser

# %%
def fix_data(df_orig):
    df=df_orig.copy(deep=True)
    #removing nan in non categorical attributes
    df['LotFrontage'].fillna(0,inplace=True)
    df['GarageYrBlt'].fillna(df['GarageYrBlt'].median(),inplace=True)
    for i in df.columns.tolist():
        if df[i].dtype==object:
            df[i]=encode(df[i])
        df[i]=normalize(df[i])
    return df

# %%
Y_df=np.log(train['SalePrice'])
X_df=train.drop(columns=['SalePrice'])

X_train=fix_data(X_df).values.T
Y_train=Y_df.values.reshape((1,X_train.shape[1]))

# %%
def initialize(X,Y):
    w=np.random.randn(1,X.shape[0])*0.001
    b=np.zeros((1,X.shape[1]))
    m=X.shape[1]
    return w,b,m

# %%
#linear model with SGD

def linreg_SGD(X,Y,learning_rate=0.0005,batch_size=32,epochs=1000,printcost=True):
    w,b,m=initialize(X,Y)
    dic={}
    b=0.0
    for i in range(1,epochs+1):
        batch_start_index=0
        if batch_size<m:
            batch_end_index=batch_size
        else:
            batch_end_index=m
        while batch_end_index<=m:
            X_batch=X[:,batch_start_index:batch_end_index]
            Y_batch=Y[:,batch_start_index:batch_end_index]
            Y_hat=np.dot(w,X_batch)+b
            diff=Y_hat-Y_batch
            loss=0.5*np.mean(np.square(diff))
            #if batch_end_index==m: print(loss)
                
            dw=1.0/batch_size*(np.dot(diff,X_batch.T))
            db=1.0/batch_size*np.sum(diff)
            w=w-learning_rate*dw
            b=b-learning_rate*db
            if batch_end_index==m:
                break
            batch_start_index+=batch_size
            batch_end_index+=batch_size
            if batch_end_index>m:
                batch_end_index=m
        dic[i]=loss
        if i%1000==0 and printcost: print('cost on epoch ',i,' is ',loss)
    return w,b,pd.Series(dic)

# %%
def evaluate(X,Y,w,b):
    pred=np.dot(w,X)+b.mean()
    mape=np.mean((np.absolute((Y-pred)/Y)))
    accuracy=100*(1-mape)
    return accuracy

# %%
w,b,loss=linreg_SGD(X_train,Y_train,batch_size=32,epochs=10000,learning_rate=0.0005)
# Out:
# cost on epoch  1000  is  0.05957862391664718
# cost on epoch  2000  is  0.05134763395892597
# cost on epoch  3000  is  0.046779325427554835
# cost on epoch  4000  is  0.04383709779073801
# cost on epoch  5000  is  0.04198508025965325
# cost on epoch  6000  is  0.040876885798429255
# cost on epoch  7000  is  0.04026994916069346
# cost on epoch  8000  is  0.03999884251820695
# cost on epoch  9000  is  0.03995184791447117
# cost on epoch  10000  is  0.040053123730257066

# %%
accuracy=evaluate(X_train,Y_train,w,b)
print("Train accuracy is %f percent" %(accuracy))
# Out:
# Train accuracy is 98.702727 percent

# %%
# Model Evaluation
Y_df=np.log(test['SalePrice'])
X_df=test.drop(columns=['SalePrice'])

X_test=fix_data(X_df).values.T
Y_test=Y_df.values.reshape((1,X_test.shape[1]))

# %%
accuracy=evaluate(X_test,Y_test,w,b)
print("Test accuracy is %f percent" %(accuracy))
# Out:
# Test accuracy is 98.098408 percent
